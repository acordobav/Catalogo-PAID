% %% [markdown]
% <div style="text-align: center; color: #0a6169" role="presentation">
% <h1 role="presentation"><strong><span role="presentation">Procesamiento y An&aacute;lisis de Im&aacute;genes Digitales - Semestre I 2020</span></strong></h1>

% %% [markdown]
% <h1 style="text-align: center;"><span style="color: steelblue;">Cat&aacute;logo Semanal</span></h1>

% %% [markdown]
% <h3><span style="text-decoration: underline;">Nombre:</span>&nbsp;Arturo Córdoba Villalobos</h3>
% <h3><span style="text-decoration: underline;">Carnet:</span>&nbsp;2016131744</h3>

% %% [markdown]
% <p><strong>Descripci&oacute;n:&nbsp;</strong>Este documento presenta un cat&aacute;logo del trabajo realizado en las clases del curso de Procesamiento y An&aacute;lisis de Im&aacute;genes Digitales.</p>

% %% [markdown]
% <h3><span style="color: #008080;"><strong>Lecciones</strong></span></h3>
%
% [<p><strong>Lecci&oacute;n 1 (Mi&eacute;rcoles 26 de Febrero)</strong></p>](leccion01.ipynb)
% Introducción a GNU Octave
%
% [<p><strong>Lecci&oacute;n 2 (Viernes 28 de Febrero)</strong></p>](leccion02.ipynb)
% Descomposición en Valores Singulares <br>
% Suma de Imágenes <br>
% Aclarar y Oscurecer una Imagen <br>
% Negativo de una imagen <br>
%
% [<p><strong>Lecci&oacute;n 3 (Miércoles 4 de Marzo)</strong></p>](leccion03.ipynb)
% Operaciones Geométricas <br>
% Rotación con Octave y un método manual <br>
%
% [<p><strong>Lecci&oacute;n 4 (Viernes 6 de Marzo)</strong></p>](leccion04.ipynb)
% Interpolación <br>
% Rotación con un método manual que conserve las esquinas <br>
%
% [<p><strong>Lecci&oacute;n 5 (Miércoles 11 de Marzo)</strong></p>](leccion05.ipynb)
% Transformación de Ondulación (Rippling) <br>
% Guardando un video con diferentes valores de la transformación rippling <br>
%
% [<p><strong>Lecci&oacute;n 6 (Viernes 13 de Marzo)</strong></p>](leccion06.ipynb)
% Transformaciones en imágenes en Escala de Grises <br>
% Transformación lineal <br>
% Transformación de autocontraste <br>
% Transformación negativa <br>
% Transformación exponencial <br>
% Transformación Logarítmica <br>
% Transformación por partes <br>
%
% [<p><strong>Lecci&oacute;n 7 (Miércoles 6 de Mayo)</strong></p>](leccion07.ipynb)
% Repaso sobre como trabajar con videos <br>
%
% [<p><strong>Lecci&oacute;n 8 (Miércoles 13 de Mayo)</strong></p>](leccion08.ipynb)
% Procesamiento de imágenes con histogramas <br>
% Técnicas para modificar imágenes con el histograma <br>
% Ecualización del Histograma <br>
%
% [<p><strong>Lecci&oacute;n 9 (Viernes 15 de Mayo)</strong></p>](leccion09.ipynb)
% Estiramiento del Histograma <br>
% Reducción del Histograma <br>
%
% [<p><strong>Lecci&oacute;n 10 (Miércoles 20 de Mayo)</strong></p>](leccion10.ipynb)
% Vecindarios y Convolución <br>
% Convolución en una dimensión para vectores de dimensión infinita <br>
% Convolución en una dimensión para vectores de dimensión finita <br>
% Convolución en dos dimensiones para matrices de dimensión finita <br>
% Aplicación de la convolución en imágenes
%
% [<p><strong>Lecci&oacute;n 11 (Viernes 22 de Mayo)</strong></p>](leccion11.ipynb)
% Operador de Sobel <br>
% Filtros en el dominio espacial <br>
% Clasificación de los filtros <br>
% Filtros Paso-Bajo <br>
% Filtro Promedio <br>
% Filtro Gaussiano <br>
% Filtro de la Media <br>
%
% [<p><strong>Lecci&oacute;n 12 (Miércoles 27 de Mayo)</strong></p>](leccion12.ipynb)
% Filtros Paso-Alto <br>
% Filtro Laplaciano <br>
% Filtro de Diferencia Direccional <br>
%
% [<p><strong>Lecci&oacute;n 13 (Viernes 29 de Mayo)</strong></p>](leccion13.ipynb)
% Filtros en el Dominio de la Frecuencia <br>
% Transformada Discreta de Fourier de 2D (DFT-2D) <br>
% Inversa de la DFT-2D <br>
% Propiedades de la DFT-2D <br>
%
% [<p><strong>Lecci&oacute;n 14 (Miércoles 3 de Junio)</strong></p>](leccion14.ipynb)
% Transformada Discreta de Fourier en 2D (DFT-2D) <br>
% Representación Gráfica de los Filtros <br>
% Filtros en el Dominio de la Frecuencia <br>
% Filtros Paso Bajo <br>
% Filtros Paso Alto <br>
% Filtro Ideal <br>
% Filtro Gaussiano <br>
% Filtro Butterworth <br>
%
% [<p><strong>Lecci&oacute;n 15 (Viernes 5 de Junio)</strong></p>](leccion15.ipynb)
% Restauración de Imágenes <br>
% Filtro de Restauración <br>
% Ruido en una Imagen <br>
% Tipos de ruido <br>
%
% [<p><strong>Lecci&oacute;n 16 (Miércoles 10 de Junio)</strong></p>](leccion16.ipynb)
% Reducción del Ruido de una Imagen en el Dominio Espacial <br>
% Técnicas para eliminar ruido aditivo en el dominio espacial <br>
% Filtro del Promedio <br>
% Filtro promedio geométrico <br>
% Filtro armónico promedio <br>
% Filtro contraarmónico promedio <br>
% Filtro de la mediana <br>
% Filtro del máximo y del mínimo <br>
% Filtro del punto medio <br>
%
% [<p><strong>Lecci&oacute;n 17 (Miércoles 17 de Junio)</strong></p>](leccion17.ipynb)
% Reducción de ruido usando técnicas en el dominio de la frecuencia <br>
% Filtro de rechazo de banda: Ideal, Butterworth y Gaussiano <br>
%
% [<p><strong>Lecci&oacute;n 18 (Viernes 19 de Junio)</strong></p>](leccion18.ipynb)
% Técnicas para eliminar difuminación de imágenes <br>
% Filtro de Wiener <br>
%
% [<p><strong>Lecci&oacute;n 19 (Miércoles 24 de Junio)</strong></p>](leccion19.ipynb)
% Procesamiento de Imágenes Morfológicas <br>
% Complemento, unión, intersección, diferencia, traslación y reflexion de imágenes <br>
% Operación de Dilatación <br>
%
% [<p><strong>Lecci&oacute;n 20 (Viernes 26 de Junio)</strong></p>](leccion20.ipynb)
% Operación de Erosión <br>
% Operadores de apertura y cierre <br>
% Algoritmos morfológicos <br>
% Extracción de bordes: interno, externo, gradiente morfológico <br>
% Rellenar huecos <br>
% Esqueleto de una figura <br>
%
% [<p><strong>Lecci&oacute;n 21 (Miércoles 1 de Julio)</strong></p>](leccion21.ipynb)
% Morfología en imágenes a escala de grises <br>
% Dilatación, erosión, apertura y closura en escala de grises <br>
% Transformadas de tipo sombrero: Top-hay, Bottom-hat <br>
%
% [<p><strong>Lecci&oacute;n 22 (Viernes 3 de Julio)</strong></p>](leccion22.ipynb)
% Detección y localización de bordes de una imagen <br>
% Detección de bordes: Laplaciano, Prewitt, Sobel <br>
% Localización de bordes: Transformada de Hough <br>
%
% [<p><strong>Lecci&oacute;n 23 (Miércoles 15 de Julio)</strong></p>](leccion23.ipynb)
% Transformada de Hough: caso específico <br>
%
% [<p><strong>Lecci&oacute;n 24 (Viernes 17 de Julio)</strong></p>](leccion24.ipynb)
% Transformada de Hough: caso general <br>
%
% [<p><strong>Lecci&oacute;n 25 (Miércoles 22 de Julio)</strong></p>](leccion25.ipynb)
% Segmentación de una imagen <br>
% La función del ruido en el procesamiento de imágenes usando umbrales <br>
% Algoritmos para detectar el umbral óptimo <br>
% Umbral global básico <br>
%
% [<p><strong>Lecci&oacute;n 26 (Viernes 24 de Julio)</strong></p>](leccion26.ipynb)
% Método de Otsu para determinar el valor de umbral <br>
% Algoritmo de Otsu <br>
% Algoritmo de Otsu para 2 umbrales <br>
%
% [<p><strong>Lecci&oacute;n 27 (Miércoles 29 de Julio)</strong></p>](leccion27.ipynb)
% Compresión de imágenes <br>
% JPEG <br>
% Transformada Discreta de Coseno de 2 Dimensiones (DCT-2D) <br>
% Cuantización <br>
%
% [<p><strong>Lecci&oacute;n 28 (Viernes 31 de Julio)</strong></p>](leccion28.ipynb)
% DCT-2D y Compresión de Imágenes <br>
% Comprimir imagen <br>
% Descomprimir imagen <br>
